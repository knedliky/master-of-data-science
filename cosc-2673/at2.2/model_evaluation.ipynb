# %%
import pandas as pd
import numpy as np
import joblib
import re
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras

# %%
lr = joblib.load('models/lr_best.sav')
l1 = joblib.load('models/l1_best.sav')
l2 = joblib.load('models/l2_best.sav')
pr = joblib.load('models/pr_best.sav')
svm = joblib.load('models/svm_best.sav')
gbr = joblib.load('models/gbr_best.sav')
xgb = joblib.load('models/xgb_best.sav')
mlp = keras.models.load_model('models/mlp.h5')

# %%
# Evaluation
from sklearn.metrics import make_scorer, mean_squared_error, r2_score

rmse = make_scorer(mean_squared_error, squared=False, greater_is_better=False)
r2 = make_scorer(r2_score)

# %%
# Data
X_test = pd.read_csv('data/test.csv')
y_test = X_test['TARGET_energy']
X_test.drop(columns=['TARGET_energy'], inplace=True)

X_test.head()
# Out:
#                   date         T1   RH_1         T2       RH_2         T3  \
# 0  2016-01-25 10:20:00  19.790000  44.06  19.066667  44.200000  20.100000
# 1  2016-02-20 12:00:00  21.033333  40.79  20.100000  41.163333  20.790000
# 2  2016-04-01 14:30:00  22.390000  38.70  22.730000  36.500000  22.290000
# 3  2016-01-22 05:20:00  18.926667  37.59  17.963333  37.500000  19.166667
# 4  2016-04-24 18:30:00  22.200000  36.00  20.000000  37.060000  22.566667
#
#     RH_3         T4       RH_4     T5  ...    T9       RH_9      T_out  \
# 0  44.20  17.600000  46.433333  17.89  ...  16.5  49.200000   9.466667
# 1  39.20  17.823333  44.126667  17.60  ...  17.7  44.090000   9.200000
# 2  37.90  21.200000  37.363333  19.70  ...  20.5  41.290000  10.750000
# 3  40.23  16.500000  38.200000  16.70  ...  16.0  42.700000  -1.133333
# 4  33.90  21.700000  33.880000  20.70  ...  20.5  34.963333   7.400000
#
#    Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# 0   763.500000  79.333333   3.333333   40.000000   5.866667  39.136068
# 1   755.000000  90.000000   6.000000   29.000000   7.700000  29.592663
# 2   760.700000  58.500000   2.500000   34.500000   2.800000   7.689350
# 3   763.933333  86.333333   3.000000   62.666667  -3.133333  42.139292
# 4   757.450000  65.000000   5.500000   40.000000   1.150000  33.962548
#
#          rv2
# 0  39.136068
# 1  29.592663
# 2   7.689350
# 3  42.139292
# 4  33.962548
#
# [5 rows x 27 columns]

# %%
# Preprocessing
from transformers import DateTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# Drop redundant features
drop = ('drop', ['rv1', 'rv2'])

# Scalers
mms = MinMaxScaler()

dt = DateTransformer(['date'])

mlp_preprocess = make_column_transformer(drop, (dt, ['date']), remainder='passthrough')
pipeline = make_pipeline(mlp_preprocess, mms, mlp)

# %%
models = [lr, l1, l2, pr, svm, gbr, xgb, mlp]
model_names = ['lr', 'l1', 'l2', 'pr', 'svm', 'gbr', 'xgb', 'mlp']
rmse_score, r2_score = [],[]

for model in models:
    if model == mlp:
        rmse_score.append(rmse(y_true=y_test, X=mlp_preprocess.fit_transform(X_test), estimator=mlp))
        r2_score.append(r2(y_true=y_test, X=mlp_preprocess.fit_transform(X_test), estimator=mlp))
        continue

    rmse_score.append(rmse(y_true=y_test, X=X_test, estimator=model))
    r2_score.append(r2(y_true=y_test, X=X_test, estimator=model))

test_eval = pd.DataFrame(zip(model_names, rmse_score, r2_score), columns=['model', 'rmse', 'r2'])
test_eval.sort_values(by='rmse', inplace=True)
test_eval
# Out:
# 124/124 [==============================] - 0s 463us/step
# 124/124 [==============================] - 0s 443us/step
#   model         rmse           r2
# 6   xgb    73.496789     0.533002
# 5   gbr    75.751863     0.503905
# 3    pr    85.624280     0.366171
# 0    lr    96.190307     0.200090
# 1    l1    96.196956     0.199980
# 2    l2    96.206243     0.199825
# 4   svm   105.498926     0.037780
# 7   mlp  4680.067487 -1892.575346
